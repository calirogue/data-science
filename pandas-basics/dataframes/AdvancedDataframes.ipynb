# %% [markdown]
# # Advance Pandas dataframes

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
# Index levels
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
outside
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
inside
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
 list(zip(outside,inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df = pd.DataFrame(randn(6,2), hier_index,['A', 'B'])

# %%
df
# Out:
#              A         B
# G1 1 -0.506387 -0.891410
#    2  1.482667  0.349367
#    3 -0.933896 -0.709348
# G2 1  1.333900 -1.705168
#    2 -0.296209 -0.313925
#    3 -0.214784  1.765326

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.506387 -0.891410
# 2  1.482667  0.349367
# 3 -0.933896 -0.709348

# %%
df.loc['G1'].loc[1]
# Out:
# A   -0.506387
# B   -0.891410
# Name: 1, dtype: float64

# %%
df
# Out:
#              A         B
# G1 1 -0.506387 -0.891410
#    2  1.482667  0.349367
#    3 -0.933896 -0.709348
# G2 1  1.333900 -1.705168
#    2 -0.296209 -0.313925
#    3 -0.214784  1.765326

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Groups', 'Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1   -0.506387 -0.891410
#        2    1.482667  0.349367
#        3   -0.933896 -0.709348
# G2     1    1.333900 -1.705168
#        2   -0.296209 -0.313925
#        3   -0.214784  1.765326

# %%
df.loc['G2']
# Out:
#             A         B
# Num
# 1    1.333900 -1.705168
# 2   -0.296209 -0.313925
# 3   -0.214784  1.765326

# %%
df.loc['G2'].loc[2]['B']
# Out:
# -0.3139248785999541

# %%
df.loc['G2'].loc[3]['A']
# Out:
# -0.21478354509096992

# %%
# Cross section
df.xs
# Out:
# <bound method NDFrame.xs of                    A         B
# Groups Num
# G1     1   -0.506387 -0.891410
#        2    1.482667  0.349367
#        3   -0.933896 -0.709348
# G2     1    1.333900 -1.705168
#        2   -0.296209 -0.313925
#        3   -0.214784  1.765326>

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1   -0.506387 -0.891410
# 2    1.482667  0.349367
# 3   -0.933896 -0.709348

# %%
df.xs(1,level='Num')
# Out:
#                A         B
# Groups
# G1     -0.506387 -0.891410
# G2      1.333900 -1.705168
